# %%
import pandas as pd

# 读取 .xls 文件
file_path = r"C:\Users\86155\Downloads\人民网.xls"
df = pd.read_excel(file_path)

# 保存为 .xlsx 格式
new_file_path = r"C:\Users\86155\Downloads\人民网sb.xlsx"
df.to_excel(new_file_path, index=False)

# %%
import pandas as pd

# %%
file_path = r"D:\我的文档\我的代码\高校大数据比赛\结果表格.csv"
df = pd.read_csv(file_path)
new_file_path = r"D:\我的文档\我的代码\高校大数据比赛\结果表格.xlsx"
df.to_excel(new_file_path, index=False)
